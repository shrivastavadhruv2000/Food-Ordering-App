# %%
class Food():
  list1=["Dhruv","Ajay"]
  def Signup(self):
    # s = input("press 1 for login and 2 for signup :")
    
    # if s=="2":
    a1 = input("enter your name: ")
    s1=a1
    b1 = int(input("phone number"))
    c1 = input("email id")
    d1 = input("address")
    e1 = input("password")
    s2=e1
    if s1 in self.list1:
        print("already exist") 
    else:
        self.list1.append(s1)
        print("register successful now login")
    print(list1)
    Id = input("enter your id")
    pa = input("enter password")
    if Id ==s1 and pa ==s2:
      print("1)place order\n2)order history\n3)update profile")
      po =int(input("enter your choice"))
      dict={1: 'Tandoori Chicken (4 pieces) [INR 240]', 
                2: 'Vegan Burger (1 Piece) [INR 320]',
                3: 'Truffle Cake (500gm) [INR 900]'}
      if po==1:
         print(dict.items())

              
         
# if the input is not-integer, just print the list
           
  def Login(self):
       a = input("enter your name")
       b = input("password") 
       for items in self.list1:
         if a in items:
            print("place order\norder history\nupdate profile") 
            po =int(input("enter your choice"))
            dict={1: 'Tandoori Chicken (4 pieces) [INR 240]', 
                2: 'Vegan Burger (1 Piece) [INR 320]',
                3: 'Truffle Cake (500gm) [INR 900]'}
            if po==1:
               print(dict.items())
  def placedOrder(self):
    try:
       self.my_list = []
      
     
       while True:
           self.my_list.append(int(input('order')))
    except:
       print('thankyou your order')
    my=['tandoori','vegan','trufle']
    for items in self.my_list:
      print(my[items-1])
       


    
    
    


              
obj = Food()
# print(obj.Signup())
print(obj.Login())

print(obj.placedOrder())
# Out:
# enter your nameAjay
# password1
# place order
# order history
# update profile
# enter your choice1
# dict_items([(1, 'Tandoori Chicken (4 pieces) [INR 240]'), (2, 'Vegan Burger (1 Piece) [INR 320]'), (3, 'Truffle Cake (500gm) [INR 900]')])
# None
# order2
# order3
# orderok
# thankyou your order
# vegan
# trufle
# None

# %% [markdown]
# a = input("enter your name")
#   b = input("password")
#   if a == "Dhruv" and b == "@321":
#     pass
#   elif a == "Ajay" and  b == "@123":
#     pass
#   else:
#     print("Invalid Id or Password")
